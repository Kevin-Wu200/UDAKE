# %% [markdown]
# # Deep Learning 基础架构教程\n本 Notebook 展示配置加载、训练和推理的最小闭环。

# %%
from deep_learning.config import ConfigLoader\ncfg = ConfigLoader().load('deep_learning/config/model_config.yaml')\ncfg['model']
